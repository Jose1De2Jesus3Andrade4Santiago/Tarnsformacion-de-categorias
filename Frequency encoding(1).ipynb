# %% [markdown]
# # Frequency Encoding

# %%
import pandas as pd

# %%
#Cargamos el DataFrame
df = pd.read_csv('ganaderia2.csv')
df.head(30)
# Out:
#    Código Ámbito          Ámbito  Código área      Área  Código Elemento  \
# 0             TA  Animales vivos           79  Alemania             5622
# 1             TA  Animales vivos           79  Alemania             5622
# 2             TA  Animales vivos           79  Alemania             5608
# 3             TA  Animales vivos           79  Alemania             5622
# 4             TA  Animales vivos           79  Alemania             5608
# 5             TA  Animales vivos           79  Alemania             5622
# 6             TA  Animales vivos           79  Alemania             5608
# 7             TA  Animales vivos           79  Alemania             5622
# 8             TA  Animales vivos           79  Alemania             5608
# 9             TA  Animales vivos           79  Alemania             5622
# 10            TA  Animales vivos           79  Alemania             5608
# 11            TA  Animales vivos           79  Alemania             5622
# 12            TA  Animales vivos           79  Alemania             5609
# 13            TA  Animales vivos           79  Alemania             5622
# 14            TA  Animales vivos           79  Alemania             5609
# 15            TA  Animales vivos           79  Alemania             5622
# 16            TA  Animales vivos           79  Alemania             5608
# 17            TA  Animales vivos           79  Alemania             5622
# 18            TA  Animales vivos           79  Alemania             5608
# 19            TA  Animales vivos           79  Alemania             5622
# 20            TA  Animales vivos           79  Alemania             5608
# 21            TA  Animales vivos           79  Alemania             5622
# 22            TA  Animales vivos           79  Alemania             5609
# 23            TA  Animales vivos           79  Alemania             5622
# 24            TA  Animales vivos           79  Alemania             5609
# 25            TA  Animales vivos           79  Alemania             5622
# 26            TA  Animales vivos            7    Angola             5622
# 27            TA  Animales vivos            7    Angola             5622
# 28            TA  Animales vivos            7    Angola             5608
# 29            TA  Animales vivos            7    Angola             5622
#
#                     Elemento  Código Producto  \
# 0        Importaciones Valor             1171
# 1        Importaciones Valor             1169
# 2   Importaciones - Cantidad             1107
# 3        Importaciones Valor             1107
# 4   Importaciones - Cantidad             1096
# 5        Importaciones Valor             1096
# 6   Importaciones - Cantidad             1126
# 7        Importaciones Valor             1126
# 8   Importaciones - Cantidad             1016
# 9        Importaciones Valor             1016
# 10  Importaciones - Cantidad             1034
# 11       Importaciones Valor             1034
# 12  Importaciones - Cantidad             1140
# 13       Importaciones Valor             1140
# 14  Importaciones - Cantidad             1057
# 15       Importaciones Valor             1057
# 16  Importaciones - Cantidad              866
# 17       Importaciones Valor              866
# 18  Importaciones - Cantidad             1110
# 19       Importaciones Valor             1110
# 20  Importaciones - Cantidad              976
# 21       Importaciones Valor              976
# 22  Importaciones - Cantidad             1068
# 23       Importaciones Valor             1068
# 24  Importaciones - Cantidad             1079
# 25       Importaciones Valor             1079
# 26       Importaciones Valor             1171
# 27       Importaciones Valor             1169
# 28  Importaciones - Cantidad             1096
# 29       Importaciones Valor             1096
#
#                                              Producto  Código año   Año  \
# 0                                  Animales vivos nep        2017  2017
# 1   Animales vivos no destinados al consumo humano...        2017  2017
# 2                                               Asnos        2017  2017
# 3                                               Asnos        2017  2017
# 4                                            Caballos        2017  2017
# 5                                            Caballos        2017  2017
# 6                                            Camellos        2017  2017
# 7                                            Camellos        2017  2017
# 8                                            Caprinos        2017  2017
# 9                                            Caprinos        2017  2017
# 10                                             Cerdos        2017  2017
# 11                                             Cerdos        2017  2017
# 12                                  Conejos y liebres        2017  2017
# 13                                  Conejos y liebres        2017  2017
# 14                                           Gallinas        2017  2017
# 15                                           Gallinas        2017  2017
# 16                                      Ganado vacuno        2017  2017
# 17                                      Ganado vacuno        2017  2017
# 18                                              Mulas        2017  2017
# 19                                              Mulas        2017  2017
# 20                                             Ovinos        2017  2017
# 21                                             Ovinos        2017  2017
# 22                                              Patos        2017  2017
# 23                                              Patos        2017  2017
# 24                                              Pavos        2017  2017
# 25                                              Pavos        2017  2017
# 26                                 Animales vivos nep        2017  2017
# 27  Animales vivos no destinados al consumo humano...        2017  2017
# 28                                           Caballos        2017  2017
# 29                                           Caballos        2017  2017
#
#           Unidad     Valor Símbolo  \
# 0       1000 US$         0     NaN
# 1       1000 US$     48326     NaN
# 2         Cabeza         5     NaN
# 3       1000 US$         3     NaN
# 4         Cabeza      1837     NaN
# 5       1000 US$     30522     NaN
# 6         Cabeza        45     NaN
# 7       1000 US$       335     NaN
# 8         Cabeza       866     NaN
# 9       1000 US$        57     NaN
# 10        Cabeza  15191521     NaN
# 11      1000 US$   1495602     NaN
# 12  1000 cabezas         3      Im
# 13      1000 US$        84     NaN
# 14  1000 cabezas    185661     NaN
# 15      1000 US$    193759     NaN
# 16        Cabeza     76414     NaN
# 17      1000 US$     69191     NaN
# 18        Cabeza         3     NaN
# 19      1000 US$         3     NaN
# 20        Cabeza    125907     NaN
# 21      1000 US$     15147     NaN
# 22  1000 cabezas      3275     NaN
# 23      1000 US$      4059     NaN
# 24  1000 cabezas      8793     NaN
# 25      1000 US$    149272     NaN
# 26      1000 US$       187       R
# 27      1000 US$       472       R
# 28        Cabeza         2       R
# 29      1000 US$        23       R
#
#                               Descripción del Símbolo
# 0                                     Datos oficiales
# 1                                     Datos oficiales
# 2                                     Datos oficiales
# 3                                     Datos oficiales
# 4                                     Datos oficiales
# 5                                     Datos oficiales
# 6                                     Datos oficiales
# 7                                     Datos oficiales
# 8                                     Datos oficiales
# 9                                     Datos oficiales
# 10                                    Datos oficiales
# 11                                    Datos oficiales
# 12  Datos de FAO basados en una metodología de imp...
# 13                                    Datos oficiales
# 14                                    Datos oficiales
# 15                                    Datos oficiales
# 16                                    Datos oficiales
# 17                                    Datos oficiales
# 18                                    Datos oficiales
# 19                                    Datos oficiales
# 20                                    Datos oficiales
# 21                                    Datos oficiales
# 22                                    Datos oficiales
# 23                                    Datos oficiales
# 24                                    Datos oficiales
# 25                                    Datos oficiales
# 26  Datos estimados utilizando la base de datos de...
# 27  Datos estimados utilizando la base de datos de...
# 28  Datos estimados utilizando la base de datos de...
# 29  Datos estimados utilizando la base de datos de...

# %%
# Extaemos la columna del Data Frame
column = df.loc[:,'Área']
column.head()
column.value_counts()
# Out:
# Alemania                       26
# Suiza                          25
# China                          22
# Angola                         18
# Turquía                        18
# Serbia                         18
# Croacia                        17
# Nepal                          17
# Colombia                       17
# Guyana                         17
# Belarús                        16
# Bulgaria                       16
# Letonia                        16
# Nicaragua                      15
# República Unida de Tanzanía    15
# Kazajstán                      15
# Gabón                          14
# Yemen                          14
# Egipto                         13
# Suecia                         13
# Barbados                       12
# Malí                           11
# Islas Caimán                    5
# Bhután                          4
# Name: Área, dtype: int64

# %%
# Ponemos la columna en una lista
column = column.values
column = column.tolist()

# %%
# Creamos un arreglo aux igual a la columna del Data Frame
aux =[]
aux= column[:]

# %%
for i in range(len(aux)):
    aux[i] = column.count(aux[i])

# %%
# Convertimos la lista en DataFrame
aux = pd.DataFrame(aux)

# %%
#Añadimos aux al DataFrame original 
df.insert(5,'Área_Fe',aux)

# %% [markdown]
# ### Eliminamos la columna original

# %%
df = df.drop('Área',axis=1)
df.head(27)
# Out:
#    Código Ámbito          Ámbito  Código área  Código Elemento  Área_Fe  \
# 0             TA  Animales vivos           79             5622       26
# 1             TA  Animales vivos           79             5622       26
# 2             TA  Animales vivos           79             5608       26
# 3             TA  Animales vivos           79             5622       26
# 4             TA  Animales vivos           79             5608       26
# 5             TA  Animales vivos           79             5622       26
# 6             TA  Animales vivos           79             5608       26
# 7             TA  Animales vivos           79             5622       26
# 8             TA  Animales vivos           79             5608       26
# 9             TA  Animales vivos           79             5622       26
# 10            TA  Animales vivos           79             5608       26
# 11            TA  Animales vivos           79             5622       26
# 12            TA  Animales vivos           79             5609       26
# 13            TA  Animales vivos           79             5622       26
# 14            TA  Animales vivos           79             5609       26
# 15            TA  Animales vivos           79             5622       26
# 16            TA  Animales vivos           79             5608       26
# 17            TA  Animales vivos           79             5622       26
# 18            TA  Animales vivos           79             5608       26
# 19            TA  Animales vivos           79             5622       26
# 20            TA  Animales vivos           79             5608       26
# 21            TA  Animales vivos           79             5622       26
# 22            TA  Animales vivos           79             5609       26
# 23            TA  Animales vivos           79             5622       26
# 24            TA  Animales vivos           79             5609       26
# 25            TA  Animales vivos           79             5622       26
# 26            TA  Animales vivos            7             5622       18
#
#                     Elemento  Código Producto  \
# 0        Importaciones Valor             1171
# 1        Importaciones Valor             1169
# 2   Importaciones - Cantidad             1107
# 3        Importaciones Valor             1107
# 4   Importaciones - Cantidad             1096
# 5        Importaciones Valor             1096
# 6   Importaciones - Cantidad             1126
# 7        Importaciones Valor             1126
# 8   Importaciones - Cantidad             1016
# 9        Importaciones Valor             1016
# 10  Importaciones - Cantidad             1034
# 11       Importaciones Valor             1034
# 12  Importaciones - Cantidad             1140
# 13       Importaciones Valor             1140
# 14  Importaciones - Cantidad             1057
# 15       Importaciones Valor             1057
# 16  Importaciones - Cantidad              866
# 17       Importaciones Valor              866
# 18  Importaciones - Cantidad             1110
# 19       Importaciones Valor             1110
# 20  Importaciones - Cantidad              976
# 21       Importaciones Valor              976
# 22  Importaciones - Cantidad             1068
# 23       Importaciones Valor             1068
# 24  Importaciones - Cantidad             1079
# 25       Importaciones Valor             1079
# 26       Importaciones Valor             1171
#
#                                              Producto  Código año   Año  \
# 0                                  Animales vivos nep        2017  2017
# 1   Animales vivos no destinados al consumo humano...        2017  2017
# 2                                               Asnos        2017  2017
# 3                                               Asnos        2017  2017
# 4                                            Caballos        2017  2017
# 5                                            Caballos        2017  2017
# 6                                            Camellos        2017  2017
# 7                                            Camellos        2017  2017
# 8                                            Caprinos        2017  2017
# 9                                            Caprinos        2017  2017
# 10                                             Cerdos        2017  2017
# 11                                             Cerdos        2017  2017
# 12                                  Conejos y liebres        2017  2017
# 13                                  Conejos y liebres        2017  2017
# 14                                           Gallinas        2017  2017
# 15                                           Gallinas        2017  2017
# 16                                      Ganado vacuno        2017  2017
# 17                                      Ganado vacuno        2017  2017
# 18                                              Mulas        2017  2017
# 19                                              Mulas        2017  2017
# 20                                             Ovinos        2017  2017
# 21                                             Ovinos        2017  2017
# 22                                              Patos        2017  2017
# 23                                              Patos        2017  2017
# 24                                              Pavos        2017  2017
# 25                                              Pavos        2017  2017
# 26                                 Animales vivos nep        2017  2017
#
#           Unidad     Valor Símbolo  \
# 0       1000 US$         0     NaN
# 1       1000 US$     48326     NaN
# 2         Cabeza         5     NaN
# 3       1000 US$         3     NaN
# 4         Cabeza      1837     NaN
# 5       1000 US$     30522     NaN
# 6         Cabeza        45     NaN
# 7       1000 US$       335     NaN
# 8         Cabeza       866     NaN
# 9       1000 US$        57     NaN
# 10        Cabeza  15191521     NaN
# 11      1000 US$   1495602     NaN
# 12  1000 cabezas         3      Im
# 13      1000 US$        84     NaN
# 14  1000 cabezas    185661     NaN
# 15      1000 US$    193759     NaN
# 16        Cabeza     76414     NaN
# 17      1000 US$     69191     NaN
# 18        Cabeza         3     NaN
# 19      1000 US$         3     NaN
# 20        Cabeza    125907     NaN
# 21      1000 US$     15147     NaN
# 22  1000 cabezas      3275     NaN
# 23      1000 US$      4059     NaN
# 24  1000 cabezas      8793     NaN
# 25      1000 US$    149272     NaN
# 26      1000 US$       187       R
#
#                               Descripción del Símbolo
# 0                                     Datos oficiales
# 1                                     Datos oficiales
# 2                                     Datos oficiales
# 3                                     Datos oficiales
# 4                                     Datos oficiales
# 5                                     Datos oficiales
# 6                                     Datos oficiales
# 7                                     Datos oficiales
# 8                                     Datos oficiales
# 9                                     Datos oficiales
# 10                                    Datos oficiales
# 11                                    Datos oficiales
# 12  Datos de FAO basados en una metodología de imp...
# 13                                    Datos oficiales
# 14                                    Datos oficiales
# 15                                    Datos oficiales
# 16                                    Datos oficiales
# 17                                    Datos oficiales
# 18                                    Datos oficiales
# 19                                    Datos oficiales
# 20                                    Datos oficiales
# 21                                    Datos oficiales
# 22                                    Datos oficiales
# 23                                    Datos oficiales
# 24                                    Datos oficiales
# 25                                    Datos oficiales
# 26  Datos estimados utilizando la base de datos de...

# %% [markdown]
# ## verificamos la exactitud del modelo con el df original y el transformado

# %%
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#Cargamos el dataset
def load_dataset(df):
    #Creamos una matriz con los datos
    dataset = df.values
    #Dividimos en X y y
    X = dataset[:, :3]
    y = dataset[:,3]
    #Forzamos el tipo string
    X = X.astype(str)
    return X, y

#Preparamos los datos de entrada, X
def prepare_inputs(X_train, X_test):
    oe = OrdinalEncoder()
    oe.fit(X_train)
    X_train_enc = oe.transform(X_train)
    X_test_enc = oe.transform(X_test)
    return X_train_enc, X_test_enc
 
#Preparamos los datos de salida, y
def prepare_targets(y_train, y_test):
    le = LabelEncoder()
    le.fit(y_train)
    y_train_enc = le.transform(y_train)
    y_test_enc = le.transform(y_test)
    return y_train_enc, y_test_enc

# %%
#Cargamos el Dataframe original
df_origin = pd.read_csv('ganaderia2.csv')

# %%
def model_accuracy(df):  
    #Cargamos el dataset
    X, y = load_dataset(df)

    #Dividimos los datos de entrada, X, y salida, y
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
    #Preparamos a X
    X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
    #Preparamos ay
    y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

    #Buscamos el modelo
    model = LogisticRegression(solver='lbfgs')
    model.fit(X_train_enc, y_train_enc)

    #Encontramos el modelo
    yhat = model.predict(X_test_enc)

    #Evaluamos el desempeño del modelo encontrado
    accuracy = accuracy_score(y_test_enc, yhat)
    return accuracy*100

# %%
print(model_accuracy(df_origin))
print(model_accuracy(df))
# Out:
# 48.0
# 56.00000000000001
# C:\Users\mrchu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\mrchu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
